# %%
import pandas as pd
import numpy as np
data=pd.read_csv('India_rainfall.csv')

# %%
a=data.head(10)
print(a)
# Out:
#    YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# 0  1901                 109.1                 241.4                 284.2
# 1  1902                 104.0                 283.7                 202.6
# 2  1903                 114.8                 293.0                 279.6
# 3  1904                 158.8                 266.4                 210.4
# 4  1905                  88.7                 252.5                 202.6
# 5  1906                 176.9                 285.8                 259.8
# 6  1907                 150.1                 223.5                 311.6
# 7  1908                 125.4                 331.5                 317.0
# 8  1909                 205.0                 318.1                 239.9
# 9  1910                 208.0                 248.1                 296.9
#
#    Actual Rainfall: SEPT  Actual Rainfall: JUN-SEPT  \
# 0                  121.9                      756.6
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 11 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   YEAR                            10 non-null     int64
#  1   Actual Rainfall: JUN            10 non-null     float64
#  2   Actual Rainfall: JUL            10 non-null     float64
#  3   Actual Rainfall: AUG            10 non-null     float64
#  4   Actual Rainfall: SEPT           10 non-null     float64
#  5   Actual Rainfall: JUN-SEPT       10 non-null     float64
#  6   Departure Percentage: JUN       10 non-null     float64
#  7   Departure Percentage: JUL       10 non-null     float64
#  8   Departure Percentage: AUG       10 non-null     float64
#  9   Departure Percentage: SEP       10 non-null     float64
#  10  Departure Percentage: JUN-SEPT  10 non-null     float64
# dtypes: float64(10), int64(1)
# memory usage: 1008.0 bytes

# %%
a.describe()
# Out:
#              YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  \
# count    10.00000              10.00000             10.000000
# mean   1905.50000             144.08000            274.400000
# std       3.02765              42.46606             34.395768
# min    1901.00000              88.70000            223.500000
# 25%    1903.25000             110.52500            249.200000
# 50%    1905.50000             137.75000            275.050000
# 75%    1907.75000             172.37500            291.200000
# max    1910.00000             208.00000            331.500000
#
#        Actual Rainfall: AUG  Actual Rainfall: SEPT  Actual Rainfall: JUN-SEPT  \
# count              10.00000              10.000000                  10.000000
# mean              260.46000             161.320000                 840.270000
# std                44.34033              36.062933                  85.116431
# min               202.60000              95.100000                 718.500000
# ...

# %%
a.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
a['Actual Rainfall: JUN'].unique()
# Out:
# array([109.1, 104. , 114.8, 158.8,  88.7, 176.9, 150.1, 125.4, 205. ,
#        208. ])

# %%
import seaborn as sns

# %%
sns.countplot(a['Actual Rainfall: JUN']).unique()
# Out:
# E:\Users\kakir\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13936\363287.py in <module>
# ----> 1 sns.countplot(a['Actual Rainfall: JUN']).unique()
#
# AttributeError: 'AxesSubplot' object has no attribute 'unique'

# %%
data.isnull()
# Out:
#       YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# 0    False                 False                 False                 False
# 1    False                 False                 False                 False
# 2    False                 False                 False                 False
# 3    False                 False                 False                 False
# 4    False                 False                 False                 False
# ..     ...                   ...                   ...                   ...
# 111  False                 False                 False                 False
# 112  False                 False                 False                 False
# 113  False                 False                 False                 False
# 114  False                 False                 False                 False
# 115  False                 False                 False                 False
#
# ...

# %%
a.corr()
# Out:
#                                     YEAR  Actual Rainfall: JUN  \
# YEAR                            1.000000              0.739834
# Actual Rainfall: JUN            0.739834              1.000000
# Actual Rainfall: JUL            0.212431              0.099975
# Actual Rainfall: AUG            0.382049              0.218471
# Actual Rainfall: SEPT          -0.011499             -0.035594
# Actual Rainfall: JUN-SEPT       0.649133              0.637909
# Departure Percentage: JUN       0.736233              0.999914
# Departure Percentage: JUL       0.219629              0.099916
# Departure Percentage: AUG       0.393543              0.225085
# Departure Percentage: SEP      -0.007014             -0.030846
# Departure Percentage: JUN-SEPT  0.656428              0.638039
#
#                                 Actual Rainfall: JUL  Actual Rainfall: AUG  \
# YEAR                                        0.212431              0.382049
# ...

# %% [markdown]
# Exploratory Data Analysis (EDA) is an approach that is used to analyze the data and discover trends, patterns, or check assumptions in data with the help of statistical summaries and graphical representations.
