# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv("India_rainfall.csv")
data
# Out:
#      YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# 0    1901                 109.1                 241.4                 284.2
# 1    1902                 104.0                 283.7                 202.6
# 2    1903                 114.8                 293.0                 279.6
# 3    1904                 158.8                 266.4                 210.4
# 4    1905                  88.7                 252.5                 202.6
# ..    ...                   ...                   ...                   ...
# 111  2012                 117.8                 250.2                 262.4
# 112  2013                 219.8                 310.0                 254.7
# 113  2014                  95.2                 261.1                 237.4
# 114  2015                 189.0                 240.8                 204.2
# 115  2016                 147.6                 309.2                 239.6
#
#      Actual Rainfall: SEPT  Actual Rainfall: JUN-SEPT  \
# ...

# %%
print(data.describe())
# Out:
#               YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  \
# count   116.000000            116.000000            116.000000
# mean   1958.500000            166.711207            294.135345
# std      33.630343             36.133349             41.531085
# min    1901.000000             85.700000            146.200000
# 25%    1929.750000            141.425000            273.575000
# 50%    1958.500000            167.250000            295.600000
# 75%    1987.250000            190.450000            322.400000
# max    2016.000000            277.200000            381.600000
#
#        Actual Rainfall: AUG  Actual Rainfall: SEPT  Actual Rainfall: JUN-SEPT  \
# count            116.000000             116.000000                 116.000000
# mean             260.920690             173.710345                 895.943966
# std               37.237717              37.492936                  92.796977
# min              189.800000              95.100000                 697.400000
# ...

# %%
a=data.head(10)
print(a)
# Out:
#    YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# 0  1901                 109.1                 241.4                 284.2
# 1  1902                 104.0                 283.7                 202.6
# 2  1903                 114.8                 293.0                 279.6
# 3  1904                 158.8                 266.4                 210.4
# 4  1905                  88.7                 252.5                 202.6
# 5  1906                 176.9                 285.8                 259.8
# 6  1907                 150.1                 223.5                 311.6
# 7  1908                 125.4                 331.5                 317.0
# 8  1909                 205.0                 318.1                 239.9
# 9  1910                 208.0                 248.1                 296.9
#
#    Actual Rainfall: SEPT  Actual Rainfall: JUN-SEPT  \
# 0                  121.9                      756.6
# ...

# %%
filtered_df = a[a['Actual Rainfall: JUN']>105]
print("\nFiltered Data:")
print(filtered_df)
# Out:
# Filtered Data:
#    YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# 0  1901                 109.1                 241.4                 284.2
# 2  1903                 114.8                 293.0                 279.6
# 3  1904                 158.8                 266.4                 210.4
# 5  1906                 176.9                 285.8                 259.8
# 6  1907                 150.1                 223.5                 311.6
# 7  1908                 125.4                 331.5                 317.0
# 8  1909                 205.0                 318.1                 239.9
# 9  1910                 208.0                 248.1                 296.9
#
#    Actual Rainfall: SEPT  Actual Rainfall: JUN-SEPT  \
# 0                  121.9                      756.6
# 2                  204.4                      891.9
# 3                  129.6                      765.2
# 5                  179.8                      902.3
# ...

# %%
filtered_data=a[a['Actual Rainfall: JUN']<200]
print(filtered_data)
# Out:
#    YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# 0  1901                 109.1                 241.4                 284.2
# 1  1902                 104.0                 283.7                 202.6
# 2  1903                 114.8                 293.0                 279.6
# 3  1904                 158.8                 266.4                 210.4
# 4  1905                  88.7                 252.5                 202.6
# 5  1906                 176.9                 285.8                 259.8
# 6  1907                 150.1                 223.5                 311.6
# 7  1908                 125.4                 331.5                 317.0
#
#    Actual Rainfall: SEPT  Actual Rainfall: JUN-SEPT  \
# 0                  121.9                      756.6
# 1                  201.9                      792.1
# 2                  204.4                      891.9
# 3                  129.6                      765.2
# ...

# %%
sorted_data = a.sort_values('Actual Rainfall: JUN')
print("Sorted Data:")
print(sorted_data)
# Out:
# Sorted Data:
#    YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# 4  1905                  88.7                 252.5                 202.6
# 1  1902                 104.0                 283.7                 202.6
# 0  1901                 109.1                 241.4                 284.2
# 2  1903                 114.8                 293.0                 279.6
# 7  1908                 125.4                 331.5                 317.0
# 6  1907                 150.1                 223.5                 311.6
# 3  1904                 158.8                 266.4                 210.4
# 5  1906                 176.9                 285.8                 259.8
# 8  1909                 205.0                 318.1                 239.9
# 9  1910                 208.0                 248.1                 296.9
#
#    Actual Rainfall: SEPT  Actual Rainfall: JUN-SEPT  \
# 4                  174.6                      718.5
# ...

# %%
sorted_data=a.sort_values('Actual Rainfall: JUN',ascending=True)
print(sorted_data)
# Out:
#    YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# 4  1905                  88.7                 252.5                 202.6
# 1  1902                 104.0                 283.7                 202.6
# 0  1901                 109.1                 241.4                 284.2
# 2  1903                 114.8                 293.0                 279.6
# 7  1908                 125.4                 331.5                 317.0
# 6  1907                 150.1                 223.5                 311.6
# 3  1904                 158.8                 266.4                 210.4
# 5  1906                 176.9                 285.8                 259.8
# 8  1909                 205.0                 318.1                 239.9
# 9  1910                 208.0                 248.1                 296.9
#
#    Actual Rainfall: SEPT  Actual Rainfall: JUN-SEPT  \
# 4                  174.6                      718.5
# ...

# %%
#sorted_data=a.sort_values('Actual Rainfall: JUN',descending=True)

# %%
sorted_data=a.sort_values('Actual Rainfall: JUN',ascending=False)
print(sorted_data)
# Out:
#    YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# 9  1910                 208.0                 248.1                 296.9
# 8  1909                 205.0                 318.1                 239.9
# 5  1906                 176.9                 285.8                 259.8
# 3  1904                 158.8                 266.4                 210.4
# 6  1907                 150.1                 223.5                 311.6
# 7  1908                 125.4                 331.5                 317.0
# 2  1903                 114.8                 293.0                 279.6
# 0  1901                 109.1                 241.4                 284.2
# 1  1902                 104.0                 283.7                 202.6
# 4  1905                  88.7                 252.5                 202.6
#
#    Actual Rainfall: SEPT  Actual Rainfall: JUN-SEPT  \
# 9                  187.2                      940.2
# ...

# %%
grouped_data = sorted_data.groupby('YEAR')#.mean()
print("Grouped Data:")
print(grouped_data)
# Out:
# Grouped Data:
# ...

# %%
grouped_data = sorted_data.groupby('YEAR').mean()
print("Grouped Data:")
print(grouped_data)
# Out:
# Grouped Data:
#       Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# YEAR
# 1901                 109.1                 241.4                 284.2
# 1902                 104.0                 283.7                 202.6
# 1903                 114.8                 293.0                 279.6
# 1904                 158.8                 266.4                 210.4
# 1905                  88.7                 252.5                 202.6
# 1906                 176.9                 285.8                 259.8
# 1907                 150.1                 223.5                 311.6
# 1908                 125.4                 331.5                 317.0
# 1909                 205.0                 318.1                 239.9
# 1910                 208.0                 248.1                 296.9
#
#       Actual Rainfall: SEPT  Actual Rainfall: JUN-SEPT  \
# YEAR
# 1901                  121.9                      756.6
# ...

# %%
#doubt
max_of_data = sorted_data.groupby('YEAR').min()
print(max_of_data)
# Out:
#       Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# YEAR
# 1901                 109.1                 241.4                 284.2
# 1902                 104.0                 283.7                 202.6
# 1903                 114.8                 293.0                 279.6
# 1904                 158.8                 266.4                 210.4
# 1905                  88.7                 252.5                 202.6
# 1906                 176.9                 285.8                 259.8
# 1907                 150.1                 223.5                 311.6
# 1908                 125.4                 331.5                 317.0
# 1909                 205.0                 318.1                 239.9
# 1910                 208.0                 248.1                 296.9
#
#       Actual Rainfall: SEPT  Actual Rainfall: JUN-SEPT  \
# YEAR
# 1901                  121.9                      756.6
# 1902                  201.9                      792.1
# ...

# %%
max_of_data = sorted_data.groupby('YEAR').max()
print(max_of_data)
# Out:
#       Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# YEAR
# 1901                 109.1                 241.4                 284.2
# 1902                 104.0                 283.7                 202.6
# 1903                 114.8                 293.0                 279.6
# 1904                 158.8                 266.4                 210.4
# 1905                  88.7                 252.5                 202.6
# 1906                 176.9                 285.8                 259.8
# 1907                 150.1                 223.5                 311.6
# 1908                 125.4                 331.5                 317.0
# 1909                 205.0                 318.1                 239.9
# 1910                 208.0                 248.1                 296.9
#
#       Actual Rainfall: SEPT  Actual Rainfall: JUN-SEPT  \
# YEAR
# 1901                  121.9                      756.6
# 1902                  201.9                      792.1
# ...

# %%
print(sorted_data['Actual Rainfall: JUN'].max())#min()
# Out:
# 208.0

# %%
print(sorted_data['YEAR'].count())
# Out:
# 10

# %%
print(sorted_data['Actual Rainfall: JUN'].sum())
# Out:
# 1440.8

# %%
grouped_data = sorted_data.groupby('YEAR').count()
print(grouped_data)
# Out:
#       Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# YEAR
# 1901                     1                     1                     1
# 1902                     1                     1                     1
# 1903                     1                     1                     1
# 1904                     1                     1                     1
# 1905                     1                     1                     1
# 1906                     1                     1                     1
# 1907                     1                     1                     1
# 1908                     1                     1                     1
# 1909                     1                     1                     1
# 1910                     1                     1                     1
#
#       Actual Rainfall: SEPT  Actual Rainfall: JUN-SEPT  \
# YEAR
# 1901                      1                          1
# 1902                      1                          1
# ...

# %%
#doubt
grouped_data = sorted_data.groupby('YEAR').sum()
print(grouped_data)
# Out:
#       Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# YEAR
# 1901                 109.1                 241.4                 284.2
# 1902                 104.0                 283.7                 202.6
# 1903                 114.8                 293.0                 279.6
# 1904                 158.8                 266.4                 210.4
# 1905                  88.7                 252.5                 202.6
# 1906                 176.9                 285.8                 259.8
# 1907                 150.1                 223.5                 311.6
# 1908                 125.4                 331.5                 317.0
# 1909                 205.0                 318.1                 239.9
# 1910                 208.0                 248.1                 296.9
#
#       Actual Rainfall: SEPT  Actual Rainfall: JUN-SEPT  \
# YEAR
# 1901                  121.9                      756.6
# 1902                  201.9                      792.1
# ...

# %% [markdown]
# describe(): This method returns description of the data in the DataFrame.
# head():This method is used to return top n (5 by default) rows of a data frame.
# Filtering, sorting and aggregation was performed on dataset.Aggregate functions such as count,sum,max,min was performed with groupby() and without groupby().
