# %%
import pandas as pd
import seaborn as sns
data = pd.read_csv("India_rainfall.csv")
data
# Out:
#      YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# 0    1901                 109.1                 241.4                 284.2
# 1    1902                 104.0                 283.7                 202.6
# 2    1903                 114.8                 293.0                 279.6
# 3    1904                 158.8                 266.4                 210.4
# 4    1905                  88.7                 252.5                 202.6
# ..    ...                   ...                   ...                   ...
# 111  2012                 117.8                 250.2                 262.4
# 112  2013                 219.8                 310.0                 254.7
# 113  2014                  95.2                 261.1                 237.4
# 114  2015                 189.0                 240.8                 204.2
# 115  2016                 147.6                 309.2                 239.6
#
#      Actual Rainfall: SEPT  Actual Rainfall: JUN-SEPT  \
# ...

# %%
a=data.head(10)
print(a)
# Out:
#    YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# 0  1901                 109.1                 241.4                 284.2
# 1  1902                 104.0                 283.7                 202.6
# 2  1903                 114.8                 293.0                 279.6
# 3  1904                 158.8                 266.4                 210.4
# 4  1905                  88.7                 252.5                 202.6
# 5  1906                 176.9                 285.8                 259.8
# 6  1907                 150.1                 223.5                 311.6
# 7  1908                 125.4                 331.5                 317.0
# 8  1909                 205.0                 318.1                 239.9
# 9  1910                 208.0                 248.1                 296.9
#
#    Actual Rainfall: SEPT  Actual Rainfall: JUN-SEPT  \
# 0                  121.9                      756.6
# ...

# %%
sns.lineplot( data['YEAR'], data['Actual Rainfall: JUN'])
# Out:
# E:\Users\kakir\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='YEAR', ylabel='Actual Rainfall: JUN'>

# %%
sns.lineplot(a['YEAR'],a['Actual Rainfall: JUN'])
# Out:
# E:\Users\kakir\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='YEAR', ylabel='Actual Rainfall: JUN'>

# %%
sns.histplot(a['Actual Rainfall: JUN'])
# Out:
# <AxesSubplot:xlabel='Actual Rainfall: JUN', ylabel='Count'>

# %%
sns.boxplot(a['Actual Rainfall: JUN'])
# Out:
# E:\Users\kakir\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Actual Rainfall: JUN'>

# %%
sns.boxplot(data['Actual Rainfall: JUN'])
# Out:
# E:\Users\kakir\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Actual Rainfall: JUN'>

# %%
sns.barplot(a['YEAR'],a['Actual Rainfall: JUN'])
# Out:
# E:\Users\kakir\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='YEAR', ylabel='Actual Rainfall: JUN'>

# %%
sns.scatterplot(a['YEAR'],a['Actual Rainfall: JUN'])
# Out:
# E:\Users\kakir\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='YEAR', ylabel='Actual Rainfall: JUN'>

# %%
sns.pointplot(a['YEAR'],a['Actual Rainfall: JUN'])
# Out:
# E:\Users\kakir\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='YEAR', ylabel='Actual Rainfall: JUN'>

# %% [markdown]
# seaborn library was imported.visualizations such as line plot,bar plot,box plot,scatter plot,histogram plot,point plot done using seaborn.
